# %%
# !python3 -m pip install opencv-python matplotlib

# %%
import cv2 as cv
from matplotlib import pyplot as plt

# %%
image = cv.imread("/Users/miguelcamargorojas/Documents/UP/PDI-Ago-dic24/images/gorra_diablos.png", 0)

# %%
type(image)
# Out:
# numpy.ndarray

# %%
image.size
# Out:
# 409600

# %%
image.shape
# Out:
# (640, 640)

# %%
plt.imshow(image, cmap="gray")
plt.show()

# %%
image[100, 300] = 0

# %%
plt.imshow(image, cmap="gray")
plt.show()
