# %%
import cv2 as cv
import numpy as np
from matplotlib import pyplot as plt

# %%
img = cv.imread("/Users/miguelcamargorojas/Documents/UP/PDI-Ago-dic24/images/rubberwhale1.png", 0)

# %%
img.shape
# Out:
# (388, 584)

# %%
img.size
# Out:
# 226592

# %%
w = np.ones((3, 3), dtype=np.uint8)

# %%
w = w * 1/9

# %%
w.sum()
# Out:
# 1.0

# %%
img_filtered = cv.filter2D(img, -1, w)

# %%
plt.imshow(np.hstack((img, img_filtered)), "gray")
plt.show()

# %%
def gen_kernel(n):
    return np.ones((n, n), dtype=np.uint8) * 1/n**2

# %%
gen_kernel(21).sum()
# Out:
# 1.0000000000000002

# %%
img_filtered = cv.filter2D(img, -1, gen_kernel(5))
plt.imshow(np.hstack((img, img_filtered)), "gray")
plt.show()
