# %%
import cv2 as cv
import numpy as np
from matplotlib import pyplot as plt

# %%
img_gray = cv.imread("/Users/miguelcamargorojas/Documents/UP/PDI-Ago-dic24/images/pic3.png", 0)

# %% [markdown]
# ---
# binarización

# %%
img_bin = cv.threshold(img_gray, 180, 255, cv.THRESH_BINARY_INV)[1]

# %%
plt.imshow(img_bin, "gray")
plt.show()

# %%
np.unique(img_bin)
# Out:
# array([  0, 255], dtype=uint8)

# %%
se = np.ones((5,5) , np.uint8)

# %% [markdown]
# ---
# Erosión

# %%
# plt.imshow(cv.erode(cv.erode(img_bin, se), se), "gray")
plt.imshow(cv.erode(img_bin, se, iterations=2), "gray")
plt.show()

# %% [markdown]
# ---
# Dilatación

# %%
plt.imshow(cv.dilate(img_bin, se, iterations=10), "gray", vmin=0)
plt.show()

# %% [markdown]
# ---
# BONUS

# %%
img_bin = cv.threshold(img_gray, 180, 255, cv.THRESH_BINARY)[1]
plt.imshow(cv.erode(img_bin, se, iterations=10), "gray", vmin=0)
plt.show()

# %% [markdown]
# ---
# Contornos

# %%
"""Detección de bordes: tomando la dilatación de una imagen y
luego restando la imagen original, se resalta así solo esos
nuevos píxeles en los bordes de los objetos que fueron
agregados por la dilatación."""

dilatada = cv.dilate(img_bin, se)

plt.imshow(dilatada - img_bin, "gray")
plt.show()

# %% [markdown]
# ---
# Remover componentes no deseados

# %%
tigre = cv.imread("/Users/miguelcamargorojas/Documents/UP/PDI-Ago-dic24/images/s&p-noise.jpeg", 0)

# %%
tigre_bin = cv.adaptiveThreshold(tigre, 255, cv.ADAPTIVE_THRESH_MEAN_C, cv.THRESH_BINARY, 11, 2)

# %%
plt.imshow(tigre_bin, "gray")
plt.show()

# %%
se_2 = np.ones((2, 2), dtype=np.uint8)

# %%
plt.imshow(cv.erode(tigre_bin, se_2), "gray")
plt.show()
